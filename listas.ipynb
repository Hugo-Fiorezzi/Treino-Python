# %%
num = [9, 5, 8, 3]
print (num)

# %%
num.sort() #Organiza em ordem crescente
print (num)

# %%
num.insert(2,1) #Coloca o 1 na posição 2

# %%
num.remove(1) #Remove o número 1

# %%
num.pop(3) #Remove o número na quarta posição

# %%
num.append(6) #Adiciona o número 6 no final da lista
