# %%
lista1 = [x for x in range (1,40) if x % 5 == 0] #Lista que achar multiplos de 5
print(lista1)

# %%
lista2 = [f'{nota} - passou' if nota >= 6 else f'{nota} - não passou' for nota in range (1,11)] #Para escrever as notas em ordem crescente
print(lista2)
