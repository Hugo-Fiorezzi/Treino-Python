# %%
Pais = {'nome': ['Brasil', 'Espanha', 'Japão'], 'capital': ['Brasilia', 'Madrid', 'Tokyo']}
print(Pais)
# Out:
# {'nome': ['Brasil', 'Espanha', 'Japão'], 'capital': ['Brasilia', 'Madrid', 'Tokyo']}

# %%
Pais['lingua'] = ['Português', 'Espanhol', 'Japonês']
print (Pais)
# Out:
# {'nome': ['Brasil', 'Espanha', 'Japão'], 'capital': ['Brasilia', 'Madrid', 'Tokyo'], 'lingua': ['Português', 'Espanhol', 'Japonês']}

# %%
del Pais ['lingua']
print(Pais)
# Out:
# {'nome': ['Brasil', 'Espanha', 'Japão'], 'capital': ['Brasilia', 'Madrid', 'Tokyo']}

# %%
alunos = {
    'Exatas' : {'nome': ['Ana', 'Carlos'], 'idade' : ['22', '19']},
    'Humanas' : {'nome' : ['João', 'Julia'], 'idade' : ['20', '18']}
}
print (alunos)
# Out:
# {'Exatas': {'nome': ['Ana', 'Carlos'], 'idade': ['22', '19']}, 'Humanas': {'nome': ['João', 'Julia'], 'idade': ['20', '18']}}
